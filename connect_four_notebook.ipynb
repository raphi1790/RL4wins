# %%
from environments.connect_four_env import ConnectFourEnv
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
env = ConnectFourEnv()

# %%
env.action_space
# Out:
# Discrete(7)

# %%
from environments.connect_four_env import RandomPlayer, ConnectFourEnv
env = ConnectFourEnv()

player1 = RandomPlayer(env, 'Dexter-Bot')
player2 = RandomPlayer(env, 'Deedee-Bot')
result = env.run(player1, player2, render=True)
reward = result.value
print(reward)
# Out:
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   | A |   |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# | B |   |   |   |   | A |   |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   | A |   |
# | B |   |   |   |   | A |   |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   | A |   |
# | B |   | B |   |   | A |   |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   | A |   |
# |   |   |   |   |   | A |   |
# | B |   | B |   |   | A |   |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   | A |   |
# |   |   |   |   |   | A |   |
# | B |   | B |   |   | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   | A |   |
# |   |   |   |   |   | A |   |
# | B |   | B |   | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   | A |   |
# |   |   | B |   |   | A |   |
# | B |   | B |   | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   |   | B |   |   | A |   |
# | B |   | B |   | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   |   | B |   |   | A |   |
# | B | B | B |   | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   |   | B |   |   | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   | B | B |   |   | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   | B | B | A |   | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   | A | B |   | A |   |
# |   | B | B | A |   | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   | A | B |   | A |   |
# | A | B | B | A |   | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   |   |   |   |   |   |
# |   |   | B |   |   |   |   |
# |   |   | A | B |   | A |   |
# | A | B | B | A |   | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   | A |   |   |   |   |
# |   |   | B |   |   |   |   |
# |   |   | A | B |   | A |   |
# | A | B | B | A |   | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   | A |   |   |   |   |
# |   |   | B |   |   | B |   |
# |   |   | A | B |   | A |   |
# | A | B | B | A |   | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   |   | B |   |   | B |   |
# |   |   | A | B |   | A |   |
# | A | B | B | A |   | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   |   | B |   |   | B |   |
# |   |   | A | B |   | A |   |
# | A | B | B | A | B | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   |   | B |   |   | B |   |
# |   | A | A | B |   | A |   |
# | A | B | B | A | B | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   |   |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   | B | B |   |   | B |   |
# |   | A | A | B |   | A |   |
# | A | B | B | A | B | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   | A |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   | B | B |   |   | B |   |
# |   | A | A | B |   | A |   |
# | A | B | B | A | B | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   | A |   |   |   |   |
# |   |   | A |   |   | A |   |
# |   | B | B |   |   | B |   |
# |   | A | A | B | B | A |   |
# | A | B | B | A | B | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   | A |   |   |   |   |
# |   | A | A |   |   | A |   |
# |   | B | B |   |   | B |   |
# |   | A | A | B | B | A |   |
# | A | B | B | A | B | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# |---+---+---+---+---+---+---|
# |   |   | A |   |   |   |   |
# |   | A | A |   |   | A |   |
# |   | B | B |   | B | B |   |
# |   | A | A | B | B | A |   |
# | A | B | B | A | B | A |   |
# | B | B | B | A | A | A | B |
# |---+---+---+---+---+---+---|
# -1
